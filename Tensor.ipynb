# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivamGupta7700/pytorch/blob/main/Tensor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print(torch.__version__)
# Out:
# 2.11.0+cu128

# %%
## Fundamentals of Tensor

# %%
#scalar

scalar = torch.tensor(7)
scalar
# Out:
# tensor(7)
